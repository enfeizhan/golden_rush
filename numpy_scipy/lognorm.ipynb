# %%
# %matplotlib inline
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
stats.lognorm.ppf([0.01, 0.5], .7, loc=-.1)
# Out:
# array([ 0.09623477,  0.9       ])

# %%
stats.norm.ppf([.1, .5, .9], loc=0)
# Out:
# array([-1.28155157,  0.        ,  1.28155157])

# %%
x = np.linspace(stats.lognorm.ppf(0.01, .7, loc=-.1), stats.lognorm.ppf(.99, .7, loc=-.1), 150)

# %%
lognormal = stats.lognorm.pdf(x, .7)

# %%
plt.plot(x, lognormal);

# %%
plt.plot(x, lognormal[::-1])

# %%
from statsmodels.stats.stattools import jarque_bera

# %%
N = 1000
M = 1000

pvalues = np.ndarray((N))

for i in range(N):
    # Draw M samples from a normal distribution 
    X = np.random.normal(0, 1, M);
    _, pvalue, _, _ = jarque_bera(X)
    pvalues[i] = pvalue
    
# count number of pvalues below our default 0.05 cutoff
num_significant = len(pvalues[pvalues < 0.05])

print(float(num_significant) / N)
# Out:
# 0.046

# %%
x = np.random.normal(0, 1, 10000)
plt.hist(x, bins=50)
jarque_bera(x)
# Out:
# (4.131623253677876,
#  0.12671540319842506,
#  0.049139265249745684,
#  3.0160382745857355)
